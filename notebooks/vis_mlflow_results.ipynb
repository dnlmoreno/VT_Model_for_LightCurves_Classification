# %%
# %cd ../
# Out:
# /n/home07/dmoreno/VisionTransformers

# %%
import mlflow
import pandas as pd
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings('ignore')

# %%
mlflow.set_tracking_uri("file:./results/ml-runs")

# %%
data_name =  'elasticc_1'
experiment_name = f"ft_classification/{data_name}/testing"

# %%
experiment = mlflow.get_experiment_by_name(experiment_name)
if experiment:
    experiment_id = experiment.experiment_id
    print(f"Experiment ID for '{experiment_name}': {experiment_id}")
else:
    print(f"Experiment '{experiment_name}' not found.")
# Out:
# Experiment ID for 'ft_classification/macho/testing': 783072213656276512

# %%
runs = mlflow.search_runs(experiment_ids=[experiment_id])
runs.columns
# Out:
# KeyboardInterrupt

# %%
filtered_runs = runs[
    (runs['params.imgs_params/input_type'] == '6grid')
]

# %%
filtered_runs = runs[
    (runs['params.loader/spc'] == '500') &
    (runs['params.imgs_params/input_type'] == 'overlay')
]

# %%
# Filtrar las corridas que coincidan con los parámetros especificados
filtered_runs = runs[
    (runs['params.loader/spc'] == '500')
]

filtered_runs #= runs.dropna()

# %%
80 * 3 * 3

# %%
order_columns = [
    #'params.loader/fold',
    'params.loader/spc',
    'metrics.epoch',
    'metrics.f1/test',
    'metrics.loss/test',
    'params.imgs_params/fig_params/linewidth',
    'params.imgs_params/fig_params/markersize',
    'params.imgs_params/input_type',
    'params.imgs_params/use_err',
    'params.training/lr',
    #'metrics.f1/val',
    #'metrics.loss/val', 
    #'metrics.f1/train',
    #'metrics.loss/train', 
    'start_time',
    'end_time',
]

# %%
order_columns = [
    'run_id',
    'status',
    'metrics.epoch',
    'metrics.f1/test',
    'metrics.loss/test',
    'params.imgs_params/fig_params/linewidth',
    'params.imgs_params/fig_params/markersize',
    'params.imgs_params/input_type',
    'params.imgs_params/use_err',
    'params.training/lr',
    #'metrics.f1/val',
    #'metrics.loss/val', 
    #'metrics.f1/train',
    #'metrics.loss/train', 
    'start_time',
    'end_time',
]

show_df = filtered_runs[order_columns]
show_df.loc[:, 'training_time'] = show_df['end_time'] - show_df['start_time']
cols = show_df.columns.tolist()
cols.insert(2, cols.pop(cols.index('training_time')))
show_df = show_df[cols].drop(['end_time', 'start_time'], axis=1)
show_df = show_df.sort_values(by=['metrics.f1/test'], ascending=False)
show_df.head(10)
# Out:
#                                run_id    status          training_time  \
# 200  42a0cec962334c108342ebd2bd88447f  FINISHED 0 days 00:58:59.660000
# 604  613b8ecbbf9d44f6bdfae175ec90a869  FINISHED 0 days 01:19:27.459000
# 212  19d5af2facbc45198e4f4579216a42a9  FINISHED 0 days 00:38:25.338000
# 26   13b1cda677f04a42b45f573b1d15caa5  FINISHED 0 days 01:14:28.576000
# 432  6f7a5d084fea445ba42cd947c89833a6  FINISHED 0 days 00:38:14.021000
# 542  265305e3360643e2a5be3e4c0e5c5bde  FINISHED 0 days 00:40:38.163000
# 762  8899bfc72492464d97be50b37474e082  FINISHED 0 days 00:45:25.012000
# 42   1a2a685ab47546379c184edaa6d92c58  FINISHED 0 days 01:35:08.056000
# 112  c75f20c7bb17498796bf6ec5bb65d0e9  FINISHED 0 days 01:08:10.231000
# 214  ff03a1fab58d4678947a5ea05c1dbb93  FINISHED 0 days 01:12:18.195000
#
#      metrics.epoch  metrics.f1/test  metrics.loss/test  \
# 200           13.0         0.836323           0.550361
# 604           21.0         0.831520           0.906421
# 212           15.0         0.830003           0.600443
# 26            18.0         0.828857           0.823754
# 432           17.0         0.824978           0.805022
# 542           17.0         0.824753           0.753789
# 762           20.0         0.822992           0.834185
# 42            26.0         0.822866           1.034389
# 112           17.0         0.822787           0.742185
# 214           19.0         0.821777           0.854723
#
#     params.imgs_params/fig_params/linewidth  \
# 200                                     1.5
# 604                                     1.0
# 212                                     1.5
# 26                                      1.0
# 432                                     1.5
# 542                                     1.5
# 762                                     1.0
# 42                                      0.5
# 112                                     0.5
# 214                                     1.5
#
#     params.imgs_params/fig_params/markersize params.imgs_params/input_type  \
# 200                                        2                         2grid
# 604                                        1                         2grid
# 212                                        2                         2grid
# 26                                         5                         2grid
# 432                                        1                       overlay
# 542                                        1                         2grid
# 762                                        1                         2grid
# 42                                         5                         2grid
# 112                                        4                       overlay
# 214                                        2                       overlay
#
#     params.imgs_params/use_err params.training/lr
# 200                       True              6e-05
# 604                       True              6e-05
# 212                      False              5e-05
# 26                        True              5e-05
# 432                      False              6e-05
# 542                      False              5e-05
# 762                      False              5e-05
# 42                        True              5e-05
# 112                       True              6e-05
# 214                       True              5e-05

# %%
order_columns = [
    'run_id',
    'status',
    'metrics.epoch',
    'metrics.f1/test',
    'metrics.loss/test',
    'params.imgs_params/fig_params/linewidth',
    'params.imgs_params/fig_params/markersize',
    'params.imgs_params/input_type',
    'params.imgs_params/use_err',
    'params.training/lr',
    #'metrics.f1/val',
    #'metrics.loss/val', 
    #'metrics.f1/train',
    #'metrics.loss/train', 
    'start_time',
    'end_time',
]

failed_show_df = failed[order_columns]
failed_show_df.loc[:, 'training_time'] = failed_show_df['end_time'] - failed_show_df['start_time']
cols = failed_show_df.columns.tolist()
cols.insert(2, cols.pop(cols.index('training_time')))
failed_show_df = failed_show_df[cols].drop(['end_time', 'start_time'], axis=1)
failed_show_df = failed_show_df.sort_values(by=['metrics.f1/test'], ascending=False)
failed_show_df.head(20)

# %%
order_columns = [
    'run_id',
    'status',
    'metrics.epoch',
    'metrics.f1/test',
    'metrics.loss/test',
    'params.imgs_params/fig_params/linewidth',
    'params.imgs_params/fig_params/markersize',
    'params.imgs_params/input_type',
    'params.imgs_params/use_err',
    'params.training/lr',
    #'metrics.f1/val',
    #'metrics.loss/val', 
    #'metrics.f1/train',
    #'metrics.loss/train', 
    'start_time',
    'end_time',
]

running_show_df = running[order_columns]
running_show_df.loc[:, 'training_time'] = running_show_df['end_time'] - running_show_df['start_time']
cols = running_show_df.columns.tolist()
cols.insert(2, cols.pop(cols.index('training_time')))
running_show_df = running_show_df[cols].drop(['end_time', 'start_time'], axis=1)
running_show_df = running_show_df.sort_values(by=['metrics.f1/test'], ascending=False)
running_show_df.head(20)

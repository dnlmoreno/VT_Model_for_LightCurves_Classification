# %%
# %cd ../
# Out:
# /home/users/dmoreno2016/VisionTransformers

# %%
import mlflow
import pandas as pd
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings('ignore')

# %%
mlflow.set_tracking_uri("file:./results/elasticc_1/ml-runs")

# %%
data_name =  'elasticc_1'
experiment_name = f"ft_classification/{data_name}/testing"

experiment = mlflow.get_experiment_by_name(experiment_name)
if experiment:
    experiment_id = experiment.experiment_id
    print(f"Experiment ID for '{experiment_name}': {experiment_id}")
else:
    print(f"Experiment '{experiment_name}' not found.")

runs = mlflow.search_runs(experiment_ids=[experiment_id])

# Filtrar las corridas que coincidan con los parámetros especificados
filtered_runs = runs[
    (runs['params.imgs_params/input_type'] == 'overlay')
]

failed = filtered_runs[filtered_runs.status == 'FAILED']
running = filtered_runs[filtered_runs.status == 'RUNNING']
finished = filtered_runs[filtered_runs.status == 'FINISHED']

print(len(failed))
print(len(running))
print(len(finished))

grouped_df = finished.groupby([
    'params.imgs_params/fig_params/linewidth',
    'params.imgs_params/fig_params/markersize',
    'params.imgs_params/input_type',
    'params.imgs_params/use_err',
    'params.training/lr',
])['metrics.f1/test'].agg(['mean', 'std']).reset_index()

grouped_df.rename(columns={'mean': 'metrics.f1/test_mean', 'std': 'metrics.f1/test_std'}, inplace=True)

print(f'Number experiments: {len(grouped_df)}')

grouped_df = grouped_df.sort_values(by=['metrics.f1/test_mean'], ascending=False)
grouped_df.head(10)
# Out:
# Experiment ID for 'ft_classification/elasticc_1/testing': 614122580949636032
# 0
# 0
# 80
# Number experiments: 80
#    params.imgs_params/fig_params/linewidth  \
# 7                                      0.5
# 39                                     1.0
# 19                                     0.5
# 75                                     2.0
# 50                                     1.5
# 47                                     1.5
# 70                                     2.0
# 35                                     1.0
# 55                                     1.5
# 3                                      0.5
#
#    params.imgs_params/fig_params/markersize params.imgs_params/input_type  \
# 7                                       2.0                       overlay
# 39                                      5.0                       overlay
# 19                                      5.0                       overlay
# 75                                      4.0                       overlay
# ...

# %%
data_name =  'elasticc_1'
experiment_name = f"ft_classification/{data_name}/testing"

experiment = mlflow.get_experiment_by_name(experiment_name)
if experiment:
    experiment_id = experiment.experiment_id
    print(f"Experiment ID for '{experiment_name}': {experiment_id}")
else:
    print(f"Experiment '{experiment_name}' not found.")

runs = mlflow.search_runs(experiment_ids=[experiment_id])

# Filtrar las corridas que coincidan con los parámetros especificados
filtered_runs = runs[
    (runs['params.imgs_params/input_type'] == '6grid')
]

failed = filtered_runs[filtered_runs.status == 'FAILED']
running = filtered_runs[filtered_runs.status == 'RUNNING']
finished = filtered_runs[filtered_runs.status == 'FINISHED']

print(len(failed))
print(len(running))
print(len(finished))

grouped_df = finished.groupby([
    'params.imgs_params/fig_params/linewidth',
    'params.imgs_params/fig_params/markersize',
    'params.imgs_params/input_type',
    'params.imgs_params/use_err',
    'params.training/lr',
])['metrics.f1/test'].agg(['mean', 'std']).reset_index()

grouped_df.rename(columns={'mean': 'metrics.f1/test_mean', 'std': 'metrics.f1/test_std'}, inplace=True)

print(f'Number experiments: {len(grouped_df)}')

grouped_df = grouped_df.sort_values(by=['metrics.f1/test_mean'], ascending=False)
grouped_df.head(10)
# Out:
# Experiment ID for 'ft_classification/elasticc_1/testing': 614122580949636032
# 12
# 12
# 36
# Number experiments: 36
#    params.imgs_params/fig_params/linewidth  \
# 2                                      0.5
# 13                                     0.5
# 10                                     0.5
# 18                                     1.0
# 5                                      0.5
# 34                                     1.5
# 22                                     1.0
# 7                                      0.5
# 25                                     1.0
# 29                                     1.5
#
#    params.imgs_params/fig_params/markersize params.imgs_params/input_type  \
# 2                                       1.0                         6grid
# 13                                      5.0                         6grid
# 10                                      4.0                         6grid
# ...
